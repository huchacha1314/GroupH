# %%
import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
from code.vae import *

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
batch_size = 128
train_loader = torch.utils.data.DataLoader(
    torchvision.datasets.MNIST('dataset', train=True, download=True,
                                transform=torchvision.transforms.ToTensor(),
                                ), batch_size=batch_size, shuffle=True)
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to dataset/MNIST/raw/train-images-idx3-ubyte.gz
#   0%|          | 0/9912422 [00:00<?, ?it/s]
# Extracting dataset/MNIST/raw/train-images-idx3-ubyte.gz to dataset/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to dataset/MNIST/raw/train-labels-idx1-ubyte.gz
#   0%|          | 0/28881 [00:00<?, ?it/s]
# Extracting dataset/MNIST/raw/train-labels-idx1-ubyte.gz to dataset/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to dataset/MNIST/raw/t10k-images-idx3-ubyte.gz
#   0%|          | 0/1648877 [00:00<?, ?it/s]
# Extracting dataset/MNIST/raw/t10k-images-idx3-ubyte.gz to dataset/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to dataset/MNIST/raw/t10k-labels-idx1-ubyte.gz
#   0%|          | 0/4542 [00:00<?, ?it/s]
# Extracting dataset/MNIST/raw/t10k-labels-idx1-ubyte.gz to dataset/MNIST/raw

# %%
test_set = torchvision.datasets.MNIST('dataset', train=False, download=True,
                                transform=torchvision.transforms.ToTensor(),
                                )
test_size=len(test_set)
test_loader = torch.utils.data.DataLoader(
    test_set, batch_size= test_size, shuffle=True)

# %%
show_mnist(3,5,train_loader)

# %%
max_epochs = 101
show_step = 100
input_size = 28 * 28
output_size = 28 * 28
latent_dim = 2
en_hidden = 256
de_hidden = 256
gendata_size = 100
vae = VAE(en_hidden, latent_dim, de_hidden, input_size, output_size)
opt = torch.optim.Adam(vae.parameters(), lr=1e-3)
loss_train = []
loss_test = []
loss_epoch = 0
i = 0
for epoch in range(max_epochs):
    print("Epoch {0}".format(epoch))
    for batch in train_loader:
        x, y = batch
        x = x.view(x.shape[0], -1)
        opt.zero_grad()
        reconstruction, mu, sigma = vae.forward_elbo(x)
        loss = 1/batch_size*-vae.loss_function(x, reconstruction, mu, sigma).mean(-1)
        loss.backward()
        opt.step()
        loss_epoch += loss
        i += 1

    loss_epoch = loss_epoch / i
    print("loss = {0}".format(loss_epoch.item()))
    loss_train.append(loss_epoch)
    loss_epoch = 0
    i = 0
    for batch_test in test_loader:
         x_test, y_test = batch_test
         x_test = x_test.view(x_test.shape[0], -1)
         with torch.no_grad():
            reconstruction_test, mu_test, sigma_test = vae.forward_elbo(x_test)
            loss = 1/test_size*-vae.loss_function(x_test, reconstruction_test, mu_test, sigma_test).mean(-1)
            loss_test.append(loss)
         if epoch == 1 or epoch == 5 or epoch == 25 or epoch == 50 or epoch == 75 or epoch == 100:
           print("latent parameters")
           show_latent_distribution(mu_test,y_test)
           print("reconstruct images")
           show_reconstruct_mnist(3, 5, reconstruction_test, y_test)
           print("generate synthetic data")
           gen_data = vae.gen_sample_data(gendata_size, latent_dim)
           show_generate_mnist(3, 5, gen_data)
# Out:
# Epoch 0
# loss = 21.584596633911133
# Epoch 1
# loss = 18.21845245361328
# latent parameters
# reconstruct images
# generate synthetic data
# Epoch 2
# loss = 17.353984832763672
# Epoch 3
# loss = 16.805479049682617
# Epoch 4
# loss = 16.320497512817383
# Epoch 5
# loss = 16.075044631958008
# latent parameters
# reconstruct images
# generate synthetic data
# Epoch 6
# loss = 15.88209342956543
# Epoch 7
# loss = 15.755913734436035
# Epoch 8
# loss = 15.60627555847168
# Epoch 9
# loss = 15.471932411193848
# Epoch 10
# loss = 15.361111640930176
# Epoch 11
# loss = 15.317519187927246
# Epoch 12
# loss = 15.1865816116333
# Epoch 13
# loss = 15.133448600769043
# Epoch 14
# loss = 15.071063995361328
# Epoch 15
# loss = 14.992411613464355
# Epoch 16
# loss = 14.972766876220703
# Epoch 17
# loss = 14.94336986541748
# Epoch 18
# loss = 14.85812759399414
# Epoch 19
# loss = 14.789199829101562
# Epoch 20
# loss = 14.661211967468262
# Epoch 21
# loss = 14.626259803771973
# Epoch 22
# loss = 14.557563781738281
# Epoch 23
# loss = 14.53150749206543
# Epoch 24
# loss = 14.499794006347656
# Epoch 25
# loss = 14.460339546203613
# latent parameters
# reconstruct images
# generate synthetic data
# Epoch 26
# loss = 14.422001838684082
# Epoch 27
# loss = 14.4613037109375
# Epoch 28
# loss = 14.394415855407715
# Epoch 29
# loss = 14.37977409362793
# Epoch 30
# loss = 14.345170021057129
# Epoch 31
# loss = 14.299757957458496
# Epoch 32
# loss = 14.275310516357422
# Epoch 33
# loss = 14.246516227722168
# Epoch 34
# loss = 14.229353904724121
# Epoch 35
# loss = 14.235597610473633
# Epoch 36
# loss = 14.196571350097656
# Epoch 37
# loss = 14.195365905761719
# Epoch 38
# loss = 14.240490913391113
# Epoch 39
# loss = 14.154641151428223
# Epoch 40
# loss = 14.159966468811035
# Epoch 41
# loss = 14.133838653564453
# Epoch 42
# loss = 14.113748550415039
# Epoch 43
# loss = 14.082486152648926
# Epoch 44
# loss = 14.06249713897705
# Epoch 45
# loss = 14.044403076171875
# Epoch 46
# loss = 13.99720573425293
# Epoch 47
# loss = 14.002795219421387
# Epoch 48
# loss = 13.979969024658203
# Epoch 49
# loss = 13.979537010192871
# Epoch 50
# loss = 13.96936321258545
# latent parameters
# reconstruct images
# generate synthetic data
# Epoch 51
# loss = 13.937568664550781
# Epoch 52
# loss = 13.918379783630371
# Epoch 53
# loss = 13.935537338256836
# Epoch 54
# loss = 13.89111614227295
# Epoch 55
# loss = 13.839923858642578
# Epoch 56
# loss = 13.83295726776123
# Epoch 57
# loss = 13.810016632080078
# Epoch 58
# loss = 13.770805358886719
# Epoch 59
# loss = 13.817133903503418
# Epoch 60
# loss = 13.80063247680664
# Epoch 61
# loss = 13.766554832458496
# Epoch 62
# loss = 13.74580192565918
# Epoch 63
# loss = 13.765763282775879
# Epoch 64
# loss = 13.741430282592773
# Epoch 65
# loss = 13.711982727050781
# Epoch 66
# loss = 13.698820114135742
# Epoch 67
# loss = 13.686628341674805
# Epoch 68
# loss = 13.6607666015625
# Epoch 69
# loss = 13.684856414794922
# Epoch 70
# loss = 13.662096977233887
# Epoch 71
# loss = 13.675738334655762
# Epoch 72
# loss = 13.691088676452637
# Epoch 73
# loss = 13.66540241241455
# Epoch 74
# loss = 13.617444038391113
# Epoch 75
# loss = 13.629193305969238
# latent parameters
# reconstruct images
# generate synthetic data
# Epoch 76
# loss = 13.606085777282715
# Epoch 77
# loss = 13.613899230957031
# Epoch 78
# loss = 13.615736961364746
# Epoch 79
# loss = 13.64201545715332
# Epoch 80
# loss = 13.62513256072998
# Epoch 81
# loss = 13.578612327575684
# Epoch 82
# loss = 13.567134857177734
# Epoch 83
# loss = 13.600015640258789
# Epoch 84
# loss = 13.551499366760254
# Epoch 85
# loss = 13.536324501037598
# Epoch 86
# loss = 13.525092124938965
# Epoch 87
# loss = 13.540014266967773
# Epoch 88
# loss = 13.502413749694824
# Epoch 89
# loss = 13.539003372192383
# Epoch 90
# loss = 13.507157325744629
# Epoch 91
# loss = 13.495047569274902
# Epoch 92
# loss = 13.524001121520996
# Epoch 93
# loss = 13.503593444824219
# Epoch 94
# loss = 13.478516578674316
# Epoch 95
# loss = 13.460050582885742
# Epoch 96
# loss = 13.476552963256836
# Epoch 97
# loss = 13.466124534606934
# Epoch 98
# loss = 13.44740104675293
# Epoch 99
# loss = 13.504924774169922
# Epoch 100
# loss = 13.477036476135254
# latent parameters
# reconstruct images
# generate synthetic data

# %%
plt.plot(np.array(loss_test), 'b')
plt.xlabel("epoch")
plt.ylabel("elbo")
plt.title("epoch vs elbo")

# %%
plt.plot(np.array(loss_train), 'b')
plt.xlabel("epoch")
plt.ylabel("elbo")
plt.title("epoch vs elbo")

# %%
max_epochs = 101
show_step = 100
input_size = 28 * 28
output_size = 28 * 28
latent_dim = 32
en_hidden = 256
de_hidden = 256
gendata_size = 100
vae = VAE(en_hidden, latent_dim, de_hidden, input_size, output_size)
opt = torch.optim.Adam(vae.parameters(), lr=1e-3)
loss_train = []
loss_test = []
loss_epoch = 0
i = 0
for epoch in range(max_epochs):
    print("Epoch {0}".format(epoch))
    for batch in train_loader:
        x, y = batch
        x = x.view(x.shape[0], -1)
        opt.zero_grad()
        reconstruction, mu, sigma = vae.forward_elbo(x)
        loss = 1/batch_size*-vae.loss_function(x, reconstruction, mu, sigma).mean(-1)
        loss.backward()
        opt.step()
        loss_epoch += loss
        i += 1

    loss_epoch = loss_epoch / i
    print("loss = {0}".format(loss_epoch.item()))
    loss_train.append(loss_epoch)
    loss_epoch = 0
    i = 0
    vae.eval()
    for batch_test in test_loader:
         x_test, y_test = batch_test
         x_test = x_test.view(x_test.shape[0], -1)
         with torch.no_grad():
            reconstruction_test, mu_test, sigma_test = vae.forward_elbo(x_test)
            loss = 1/test_size*-vae.loss_function(x_test, reconstruction_test, mu_test, sigma_test).mean(-1)
            loss_test.append(loss)
         if epoch == 1 or epoch == 5 or epoch == 25 or epoch == 50 or epoch == 75 or epoch == 100:
           print("reconstruct images")
           
           show_reconstruct_mnist(3, 5, reconstruction_test, y_test)
           print("generate synthetic data")
           
           gen_data = vae.gen_sample_data(gendata_size, latent_dim)
           show_generate_mnist(3, 5, gen_data)
    vae.train()
# Out:
# Epoch 0
# loss = 14.911398887634277
# Epoch 1
# loss = 8.117934226989746
# reconstruct images
# generate synthetic data
# Epoch 2
# loss = 6.70602560043335
# Epoch 3
# loss = 6.097911834716797
# Epoch 4
# loss = 5.711389541625977
# Epoch 5
# loss = 5.446466445922852
# reconstruct images
# generate synthetic data
# Epoch 6
# loss = 5.246913433074951
# Epoch 7
# loss = 5.095416069030762
# Epoch 8
# loss = 4.975135803222656
# Epoch 9
# loss = 4.876899719238281
# Epoch 10
# loss = 4.799817085266113
# Epoch 11
# loss = 4.725122451782227
# Epoch 12
# loss = 4.677506446838379
# Epoch 13
# loss = 4.6263275146484375
# Epoch 14
# loss = 4.584232330322266
# Epoch 15
# loss = 4.542413234710693
# Epoch 16
# loss = 4.5100417137146
# Epoch 17
# loss = 4.4836883544921875
# Epoch 18
# loss = 4.450711250305176
# Epoch 19
# loss = 4.433425426483154
# Epoch 20
# loss = 4.40770959854126
# Epoch 21
# loss = 4.390488147735596
# Epoch 22
# loss = 4.3667731285095215
# Epoch 23
# loss = 4.35369873046875
# Epoch 24
# loss = 4.331984996795654
# Epoch 25
# loss = 4.327028274536133
# reconstruct images
# generate synthetic data
# Epoch 26
# loss = 4.308789253234863
# Epoch 27
# loss = 4.298673152923584
# Epoch 28
# loss = 4.289307594299316
# Epoch 29
# loss = 4.276607513427734
# Epoch 30
# loss = 4.26271390914917
# Epoch 31
# loss = 4.250202178955078
# Epoch 32
# loss = 4.245703220367432
# Epoch 33
# loss = 4.238207817077637
# Epoch 34
# loss = 4.2289137840271
# Epoch 35
# loss = 4.2198076248168945
# Epoch 36
# loss = 4.211271286010742
# Epoch 37
# loss = 4.202801704406738
# Epoch 38
# loss = 4.19502067565918
# Epoch 39
# loss = 4.187299728393555
# Epoch 40
# loss = 4.181858062744141
# Epoch 41
# loss = 4.1782660484313965
# Epoch 42
# loss = 4.172562122344971
# Epoch 43
# loss = 4.162236213684082
# Epoch 44
# loss = 4.156519412994385
# Epoch 45
# loss = 4.156306266784668
# Epoch 46
# loss = 4.146580219268799
# Epoch 47
# loss = 4.1383490562438965
# Epoch 48
# loss = 4.137073993682861
# Epoch 49
# loss = 4.127758026123047
# Epoch 50
# loss = 4.128780364990234
# reconstruct images
# generate synthetic data
# Epoch 51
# loss = 4.118899345397949
# Epoch 52
# loss = 4.121112823486328
# Epoch 53
# loss = 4.112434387207031
# Epoch 54
# loss = 4.109591484069824
# Epoch 55
# loss = 4.104793548583984
# Epoch 56
# loss = 4.100104808807373
# Epoch 57
# loss = 4.095405578613281
# Epoch 58
# loss = 4.092153549194336
# Epoch 59
# loss = 4.088691711425781
# Epoch 60
# loss = 4.085870742797852
# Epoch 61
# loss = 4.075695991516113
# Epoch 62
# loss = 4.080954551696777
# Epoch 63
# loss = 4.075318336486816
# Epoch 64
# loss = 4.067734241485596
# Epoch 65
# loss = 4.064883232116699
# Epoch 66
# loss = 4.068077087402344
# Epoch 67
# loss = 4.060362815856934
# Epoch 68
# loss = 4.058872222900391
# Epoch 69
# loss = 4.051444053649902
# Epoch 70
# loss = 4.050286769866943
# Epoch 71
# loss = 4.049093723297119
# Epoch 72
# loss = 4.041548252105713
# Epoch 73
# loss = 4.041108131408691
# Epoch 74
# loss = 4.0420684814453125
# Epoch 75
# loss = 4.032793998718262
# reconstruct images
# generate synthetic data
# Epoch 76
# loss = 4.030893325805664
# Epoch 77
# loss = 4.032728672027588
# Epoch 78
# loss = 4.023833274841309
# Epoch 79
# loss = 4.023516654968262
# Epoch 80
# loss = 4.022498607635498
# Epoch 81
# loss = 4.019125938415527
# Epoch 82
# loss = 4.0179033279418945
# Epoch 83
# loss = 4.0091986656188965
# Epoch 84
# loss = 4.0121612548828125
# Epoch 85
# loss = 4.009622097015381
# Epoch 86
# loss = 4.006620407104492
# Epoch 87
# loss = 4.003274440765381
# Epoch 88
# loss = 4.0013108253479
# Epoch 89
# loss = 4.000999927520752
# Epoch 90
# loss = 3.995866060256958
# Epoch 91
# loss = 3.993877410888672
# Epoch 92
# loss = 3.9938902854919434
# Epoch 93
# loss = 3.9900436401367188
# Epoch 94
# loss = 3.9918243885040283
# Epoch 95
# loss = 3.9911093711853027
# Epoch 96
# loss = 3.9843180179595947
# Epoch 97
# loss = 3.983156681060791
# Epoch 98
# loss = 3.982865333557129
# Epoch 99
# loss = 3.979109048843384
# Epoch 100
# loss = 3.9767024517059326
# reconstruct images
# generate synthetic data

# %%
plt.plot(np.array(loss_test), 'b')
plt.xlabel("epoch")
plt.ylabel("elbo")
plt.title("epoch vs elbo")
# Out:
# Text(0.5, 1.0, 'epoch vs elbo')
